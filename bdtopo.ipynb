# %%
# !pip install -q -q -q geopandas

# %%
# !pip install -q -q -q py7zr

# %%
import geopandas as gpd
import urllib.request
import os
from py7zr import unpack_7zarchive
import shutil
shutil.register_unpack_format('7zip', ['.7z'], unpack_7zarchive)

# %%
urllib.request.urlretrieve('ftp://BDTOPO_V3_ext:Aish3ho8!!!@ftp3.ign.fr/BDTOPO_3-0_2021-03-15/BDTOPO_3-0_TOUSTHEMES_SHP_LAMB93_D050_2021-03-15.7z', 'd050.7z')
urllib.request.urlretrieve('ftp://BDTOPO_V3_ext:Aish3ho8!!!@ftp3.ign.fr/BDTOPO_3-0_2021-03-15/BDTOPO_3-0_TOUSTHEMES_SHP_LAMB93_D051_2021-03-15.7z', 'd051.7z')
# Out:
# ('d050.7z', <email.message.Message at 0x7efca8490e50>)

# %%
shutil.unpack_archive('d050.7z', '')
shutil.unpack_archive('d051.7z', '')

# %%
bati50 = gpd.read_file('BDTOPO_3-0_TOUSTHEMES_SHP_LAMB93_D050_2021-03-15/BDTOPO/1_DONNEES_LIVRAISON_2021-03-00272/BDT_3-0_SHP_LAMB93_D050-ED2021-03-15/BATI/BATIMENT.shp',
                       bbox=(387380 - 16000, 6893920 - 16000,387380 + 16000, 6893920 + 16000))

# %%
bati50.plot()

# %%
bati51 = gpd.read_file('BDTOPO_3-0_TOUSTHEMES_SHP_LAMB93_D051_2021-03-15/BDTOPO/1_DONNEES_LIVRAISON_2021-03-00272/BDT_3-0_SHP_LAMB93_D051-ED2021-03-15/BATI/BATIMENT.shp',
                       bbox=(786645-16000,6879505-16000,786645+16000,6879505+16000))

# %%
bati51.plot()

# %%
bati50.to_file('building_bocage.gpkg', driver='GPKG')

# %%
bati51.to_file('building_openfield.gpkg', driver='GPKG')
